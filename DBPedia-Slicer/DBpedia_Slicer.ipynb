# %% [markdown]
# # DBpedia Slicer
# This notewook allows you to slide some entities from DBpedia
#
# ## Importing Libraries
# First, we will import the required libraries.
# To install rdflib and SPARQLWrapper execute the following command in a new cell
#
# ```
# !pip install SPARQLWrapper
# ```

# %%
import random
import rdflib
from SPARQLWrapper import SPARQLWrapper, JSON, POST, N3
import requests as rq
from requests import Request, Session
import codecs
import sys
import json

# %% [markdown]
# We set up the encoding of the system to UTF-8

# %%
#reload(sys)
#sys.setdefaultencoding("utf-8")

# %% [markdown]
# We define globla variables with the end-points

# %%
endpoint = "http://dbpedia.org/sparql"
wikidata = "https://query.wikidata.org/sparql"
dydra = "https://dydra.com/mgalkin/dbpedia_hierarchy/sparql"

# %% [markdown]
# ## Implemeting methods
# Method to check the number of triples by type e.g., Person

# %%
def checkNumTriples(eType):
    query = """
            PREFIX dbpedia-owl: <http://dbpedia.org/ontology/>
            SELECT COUNT(?s) as ?num
            WHERE {
                # ?s a dbpedia-owl:%s
            }
    """ % eType
    gg = SPARQLWrapper(endpoint)
    gg.setQuery(query)
    gg.setReturnFormat(JSON)
    results = gg.query().convert()
    
    return results["results"]["bindings"][0]["num"]["value"]

# %% [markdown]
# Method to get the subjects

# %%
def createTrainingData(eType, includeAbs):
    print("Process starting")
    gg = SPARQLWrapper(endpoint)
    gg.setReturnFormat(JSON)
    
    count = int(checkNumTriples(eType)) #900
    print("# of %s: %s"%(eType, count))
    
    file = codecs.open(eType+"_Training_data.txt","w","utf-8")
    limit = 500
    offset = 0
    
    while (count > offset): 
        query = """
            PREFIX dbpedia-owl: <http://dbpedia.org/ontology/>
            PREFIX dbp: <http://dbpedia.org/property/>
            PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
           
            SELECT ?s ?n ?abs
            WHERE {
                # ?s a dbpedia-owl:%s .
                # ?s rdfs:label ?n .
                # ?s rdfs:comment ?abs .
                FILTER (lang(?n) = 'en' and lang(?abs) = 'en')
            } LIMIT %s OFFSET  %s
        """ %(eType, limit, offset)

        print ("Query next batch %s - %s" %(offset, offset + limit))
        
        gg.setQuery(query)
        results = gg.query().convert()
        i = 0

        for result in results["results"]["bindings"]:
            #if "DB" not in result["n"]["value"]:
            #    continue
            subject = result["s"]["value"]
            name = result["n"]["value"]

            # Print the cost every 100 training examples
            i = i + 1
            if i % 1000 == 0:
                print ("%s - Example of data %s: %s" %(i, subject, name))

            if includeAbs == True:
                abst = result["abs"]["value"]
                file.write("<"+subject+">\t"+name+"\t"+abst+"\n")
            else:
                file.write("<"+subject+">\t"+name+"\n")
            
        offset = offset + limit
    
    file.close()
    print("Process finished")

# %% [markdown]
# ## Main method
# Now we use the functions we have implemented before, the supported types are: Person, Organisation, Drug, Event... and all DBpedia classes.

# %%
createTrainingData("Organisation", True)
# Out:
# Process starting
# # of Organisation: 352081
# Query next batch 0 - 500
# Query next batch 500 - 1000
# Query next batch 1000 - 1500
# Query next batch 1500 - 2000
# Query next batch 2000 - 2500
# Query next batch 2500 - 3000
# Query next batch 3000 - 3500
# Query next batch 3500 - 4000
# Query next batch 4000 - 4500
# Query next batch 4500 - 5000
# Query next batch 5000 - 5500
# Query next batch 5500 - 6000
# Query next batch 6000 - 6500
# Query next batch 6500 - 7000
# Query next batch 7000 - 7500
# Query next batch 7500 - 8000
# Query next batch 8000 - 8500
# Query next batch 8500 - 9000
# Query next batch 9000 - 9500
# Query next batch 9500 - 10000
# Query next batch 10000 - 10500
# Query next batch 10500 - 11000
# Query next batch 11000 - 11500
# Query next batch 11500 - 12000
# Query next batch 12000 - 12500
# Query next batch 12500 - 13000
# Query next batch 13000 - 13500
# Query next batch 13500 - 14000
# Query next batch 14000 - 14500
# Query next batch 14500 - 15000
# Query next batch 15000 - 15500
# Query next batch 15500 - 16000
# Query next batch 16000 - 16500
# Query next batch 16500 - 17000
# Query next batch 17000 - 17500
# Query next batch 17500 - 18000
# Query next batch 18000 - 18500
# Query next batch 18500 - 19000
# Query next batch 19000 - 19500
# Query next batch 19500 - 20000
# Query next batch 20000 - 20500
# Query next batch 20500 - 21000
# Query next batch 21000 - 21500
# Query next batch 21500 - 22000
# Query next batch 22000 - 22500
# Query next batch 22500 - 23000
# Query next batch 23000 - 23500
# Query next batch 23500 - 24000
# Query next batch 24000 - 24500
# Query next batch 24500 - 25000
# Query next batch 25000 - 25500
# Query next batch 25500 - 26000
# Query next batch 26000 - 26500
# Query next batch 26500 - 27000
# Query next batch 27000 - 27500
# Query next batch 27500 - 28000
# Query next batch 28000 - 28500
# Query next batch 28500 - 29000
# Query next batch 29000 - 29500
# Query next batch 29500 - 30000
# Query next batch 30000 - 30500
# Query next batch 30500 - 31000
# Query next batch 31000 - 31500
# Query next batch 31500 - 32000
# Query next batch 32000 - 32500
# Query next batch 32500 - 33000
# Query next batch 33000 - 33500
# Query next batch 33500 - 34000
# Query next batch 34000 - 34500
# Query next batch 34500 - 35000
# Query next batch 35000 - 35500
# Query next batch 35500 - 36000
# Query next batch 36000 - 36500
# Query next batch 36500 - 37000
# Query next batch 37000 - 37500
# Query next batch 37500 - 38000
# Query next batch 38000 - 38500
# Query next batch 38500 - 39000
# Query next batch 39000 - 39500
# Query next batch 39500 - 40000
# Query next batch 40000 - 40500
# Query next batch 40500 - 41000
# Query next batch 41000 - 41500
# Query next batch 41500 - 42000
# Query next batch 42000 - 42500
# Query next batch 42500 - 43000
# Query next batch 43000 - 43500
# Query next batch 43500 - 44000
# Query next batch 44000 - 44500
# Query next batch 44500 - 45000
# Query next batch 45000 - 45500
# Query next batch 45500 - 46000
# Query next batch 46000 - 46500
# Query next batch 46500 - 47000
# Query next batch 47000 - 47500
# Query next batch 47500 - 48000
# Query next batch 48000 - 48500
# Query next batch 48500 - 49000
# Query next batch 49000 - 49500
# Query next batch 49500 - 50000
# Query next batch 50000 - 50500
# Query next batch 50500 - 51000
# Query next batch 51000 - 51500
# Query next batch 51500 - 52000
# Query next batch 52000 - 52500
# Query next batch 52500 - 53000
# Query next batch 53000 - 53500
# Query next batch 53500 - 54000
# Query next batch 54000 - 54500
# Query next batch 54500 - 55000
# Query next batch 55000 - 55500
# Query next batch 55500 - 56000
# Query next batch 56000 - 56500
# Query next batch 56500 - 57000
# Query next batch 57000 - 57500
# Query next batch 57500 - 58000
# Query next batch 58000 - 58500
# Query next batch 58500 - 59000
# Query next batch 59000 - 59500
# Query next batch 59500 - 60000
# Query next batch 60000 - 60500
# Query next batch 60500 - 61000
# Query next batch 61000 - 61500
# Query next batch 61500 - 62000
# Query next batch 62000 - 62500
# Query next batch 62500 - 63000
# Query next batch 63000 - 63500
# Query next batch 63500 - 64000
# Query next batch 64000 - 64500
# Query next batch 64500 - 65000
# Query next batch 65000 - 65500
# Query next batch 65500 - 66000
# Query next batch 66000 - 66500
# Query next batch 66500 - 67000
# Query next batch 67000 - 67500
# Query next batch 67500 - 68000
# Query next batch 68000 - 68500
# Query next batch 68500 - 69000
# Query next batch 69000 - 69500
# Query next batch 69500 - 70000
# Query next batch 70000 - 70500
# Query next batch 70500 - 71000
# Query next batch 71000 - 71500
# Query next batch 71500 - 72000
# Query next batch 72000 - 72500
# Query next batch 72500 - 73000
# Query next batch 73000 - 73500
# Query next batch 73500 - 74000
# Query next batch 74000 - 74500
# Query next batch 74500 - 75000
# Query next batch 75000 - 75500
# Query next batch 75500 - 76000
# Query next batch 76000 - 76500
# Query next batch 76500 - 77000
# Query next batch 77000 - 77500
# Query next batch 77500 - 78000
# Query next batch 78000 - 78500
# Query next batch 78500 - 79000
# Query next batch 79000 - 79500
# Query next batch 79500 - 80000
# Query next batch 80000 - 80500
# Query next batch 80500 - 81000
# Query next batch 81000 - 81500
# Query next batch 81500 - 82000
# Query next batch 82000 - 82500
# Query next batch 82500 - 83000
# Query next batch 83000 - 83500
# Query next batch 83500 - 84000
# Query next batch 84000 - 84500
# Query next batch 84500 - 85000
# Query next batch 85000 - 85500
# Query next batch 85500 - 86000
# Query next batch 86000 - 86500
# Query next batch 86500 - 87000
# Query next batch 87000 - 87500
# Query next batch 87500 - 88000
# Query next batch 88000 - 88500
# Query next batch 88500 - 89000
# Query next batch 89000 - 89500
# Query next batch 89500 - 90000
# Query next batch 90000 - 90500
# Query next batch 90500 - 91000
# Query next batch 91000 - 91500
# Query next batch 91500 - 92000
# Query next batch 92000 - 92500
# Query next batch 92500 - 93000
# Query next batch 93000 - 93500
# Query next batch 93500 - 94000
# Query next batch 94000 - 94500
# Query next batch 94500 - 95000
# Query next batch 95000 - 95500
# Query next batch 95500 - 96000
# Query next batch 96000 - 96500
# Query next batch 96500 - 97000
# Query next batch 97000 - 97500
# Query next batch 97500 - 98000
# Query next batch 98000 - 98500
# Query next batch 98500 - 99000
# Query next batch 99000 - 99500
# Query next batch 99500 - 100000
# Query next batch 100000 - 100500
# Query next batch 100500 - 101000
# Query next batch 101000 - 101500
# Query next batch 101500 - 102000
# Query next batch 102000 - 102500
# Query next batch 102500 - 103000
# Query next batch 103000 - 103500
# Query next batch 103500 - 104000
# Query next batch 104000 - 104500
# Query next batch 104500 - 105000
# Query next batch 105000 - 105500
# Query next batch 105500 - 106000
# Query next batch 106000 - 106500
# Query next batch 106500 - 107000
# Query next batch 107000 - 107500
# Query next batch 107500 - 108000
# Query next batch 108000 - 108500
# Query next batch 108500 - 109000
# Query next batch 109000 - 109500
# Query next batch 109500 - 110000
# Query next batch 110000 - 110500
# Query next batch 110500 - 111000
# Query next batch 111000 - 111500
# Query next batch 111500 - 112000
# Query next batch 112000 - 112500
# Query next batch 112500 - 113000
# Query next batch 113000 - 113500
# Query next batch 113500 - 114000
# Query next batch 114000 - 114500
# Query next batch 114500 - 115000
# Query next batch 115000 - 115500
# Query next batch 115500 - 116000
# Query next batch 116000 - 116500
# Query next batch 116500 - 117000
# Query next batch 117000 - 117500
# Query next batch 117500 - 118000
# Query next batch 118000 - 118500
# Query next batch 118500 - 119000
# Query next batch 119000 - 119500
# Query next batch 119500 - 120000
# Query next batch 120000 - 120500
# Query next batch 120500 - 121000
# Query next batch 121000 - 121500
# Query next batch 121500 - 122000
# Query next batch 122000 - 122500
# Query next batch 122500 - 123000
# Query next batch 123000 - 123500
# Query next batch 123500 - 124000
# Query next batch 124000 - 124500
# Query next batch 124500 - 125000
# Query next batch 125000 - 125500
# Query next batch 125500 - 126000
# Query next batch 126000 - 126500
# Query next batch 126500 - 127000
# Query next batch 127000 - 127500
# Query next batch 127500 - 128000
# Query next batch 128000 - 128500
# Query next batch 128500 - 129000
# Query next batch 129000 - 129500
# Query next batch 129500 - 130000
# Query next batch 130000 - 130500
# Query next batch 130500 - 131000
# Query next batch 131000 - 131500
# Query next batch 131500 - 132000
# Query next batch 132000 - 132500
# Query next batch 132500 - 133000
# Query next batch 133000 - 133500
# Query next batch 133500 - 134000
# Query next batch 134000 - 134500
# Query next batch 134500 - 135000
# Query next batch 135000 - 135500
# Query next batch 135500 - 136000
# Query next batch 136000 - 136500
# Query next batch 136500 - 137000
# Query next batch 137000 - 137500
# Query next batch 137500 - 138000
# Query next batch 138000 - 138500
# Query next batch 138500 - 139000
# Query next batch 139000 - 139500
# Query next batch 139500 - 140000
# Query next batch 140000 - 140500
# Query next batch 140500 - 141000
# Query next batch 141000 - 141500
# Query next batch 141500 - 142000
# Query next batch 142000 - 142500
# Query next batch 142500 - 143000
# Query next batch 143000 - 143500
# Query next batch 143500 - 144000
# Query next batch 144000 - 144500
# Query next batch 144500 - 145000
# Query next batch 145000 - 145500
# Query next batch 145500 - 146000
# Query next batch 146000 - 146500
# Query next batch 146500 - 147000
# Query next batch 147000 - 147500
# Query next batch 147500 - 148000
# Query next batch 148000 - 148500
# Query next batch 148500 - 149000
# Query next batch 149000 - 149500
# Query next batch 149500 - 150000
# Query next batch 150000 - 150500
# Query next batch 150500 - 151000
# Query next batch 151000 - 151500
# Query next batch 151500 - 152000
# Query next batch 152000 - 152500
# Query next batch 152500 - 153000
# Query next batch 153000 - 153500
# Query next batch 153500 - 154000
# Query next batch 154000 - 154500
# Query next batch 154500 - 155000
# Query next batch 155000 - 155500
# Query next batch 155500 - 156000
# Query next batch 156000 - 156500
# Query next batch 156500 - 157000
# Query next batch 157000 - 157500
# Query next batch 157500 - 158000
# Query next batch 158000 - 158500
# Query next batch 158500 - 159000
# Query next batch 159000 - 159500
# Query next batch 159500 - 160000
# Query next batch 160000 - 160500
# Query next batch 160500 - 161000
# Query next batch 161000 - 161500
# Query next batch 161500 - 162000
# Query next batch 162000 - 162500
# Query next batch 162500 - 163000
# Query next batch 163000 - 163500
# Query next batch 163500 - 164000
# Query next batch 164000 - 164500
# Query next batch 164500 - 165000
# Query next batch 165000 - 165500
# Query next batch 165500 - 166000
# Query next batch 166000 - 166500
# Query next batch 166500 - 167000
# Query next batch 167000 - 167500
# Query next batch 167500 - 168000
# Query next batch 168000 - 168500
# Query next batch 168500 - 169000
# Query next batch 169000 - 169500
# Query next batch 169500 - 170000
# Query next batch 170000 - 170500
# Query next batch 170500 - 171000
# Query next batch 171000 - 171500
# Query next batch 171500 - 172000
# Query next batch 172000 - 172500
# Query next batch 172500 - 173000
# Query next batch 173000 - 173500
# Query next batch 173500 - 174000
# Query next batch 174000 - 174500
# Query next batch 174500 - 175000
# Query next batch 175000 - 175500
# Query next batch 175500 - 176000
# Query next batch 176000 - 176500
# Query next batch 176500 - 177000
# Query next batch 177000 - 177500
# Query next batch 177500 - 178000
# Query next batch 178000 - 178500
# Query next batch 178500 - 179000
# Query next batch 179000 - 179500
# Query next batch 179500 - 180000
# Query next batch 180000 - 180500
# Query next batch 180500 - 181000
# Query next batch 181000 - 181500
# Query next batch 181500 - 182000
# Query next batch 182000 - 182500
# Query next batch 182500 - 183000
# Query next batch 183000 - 183500
# Query next batch 183500 - 184000
# Query next batch 184000 - 184500
# Query next batch 184500 - 185000
# Query next batch 185000 - 185500
# Query next batch 185500 - 186000
# Query next batch 186000 - 186500
# Query next batch 186500 - 187000
# Query next batch 187000 - 187500
# Query next batch 187500 - 188000
# Query next batch 188000 - 188500
# Query next batch 188500 - 189000
# Query next batch 189000 - 189500
# Query next batch 189500 - 190000
# Query next batch 190000 - 190500
# Query next batch 190500 - 191000
# Query next batch 191000 - 191500
# Query next batch 191500 - 192000
# Query next batch 192000 - 192500
# Query next batch 192500 - 193000
# Query next batch 193000 - 193500
# Query next batch 193500 - 194000
# Query next batch 194000 - 194500
# Query next batch 194500 - 195000
# Query next batch 195000 - 195500
# Query next batch 195500 - 196000
# Query next batch 196000 - 196500
# Query next batch 196500 - 197000
# Query next batch 197000 - 197500
# Query next batch 197500 - 198000
# Query next batch 198000 - 198500
# Query next batch 198500 - 199000
# Query next batch 199000 - 199500
# Query next batch 199500 - 200000
# Query next batch 200000 - 200500
# Query next batch 200500 - 201000
# Query next batch 201000 - 201500
# Query next batch 201500 - 202000
# Query next batch 202000 - 202500
# Query next batch 202500 - 203000
# Query next batch 203000 - 203500
# Query next batch 203500 - 204000
# Query next batch 204000 - 204500
# Query next batch 204500 - 205000
# Query next batch 205000 - 205500
# Query next batch 205500 - 206000
# Query next batch 206000 - 206500
# Query next batch 206500 - 207000
# Query next batch 207000 - 207500
# Query next batch 207500 - 208000
# Query next batch 208000 - 208500
# Query next batch 208500 - 209000
# Query next batch 209000 - 209500
# Query next batch 209500 - 210000
# Query next batch 210000 - 210500
# Query next batch 210500 - 211000
# Query next batch 211000 - 211500
# Query next batch 211500 - 212000
# Query next batch 212000 - 212500
# Query next batch 212500 - 213000
# Query next batch 213000 - 213500
# Query next batch 213500 - 214000
# Query next batch 214000 - 214500
# Query next batch 214500 - 215000
# Query next batch 215000 - 215500
# Query next batch 215500 - 216000
# Query next batch 216000 - 216500
# Query next batch 216500 - 217000
# Query next batch 217000 - 217500
# Query next batch 217500 - 218000
# Query next batch 218000 - 218500
# Query next batch 218500 - 219000
# Query next batch 219000 - 219500
# Query next batch 219500 - 220000
# Query next batch 220000 - 220500
# Query next batch 220500 - 221000
# Query next batch 221000 - 221500
# Query next batch 221500 - 222000
# Query next batch 222000 - 222500
# Query next batch 222500 - 223000
# Query next batch 223000 - 223500
# Query next batch 223500 - 224000
# Query next batch 224000 - 224500
# Query next batch 224500 - 225000
# Query next batch 225000 - 225500
# Query next batch 225500 - 226000
# Query next batch 226000 - 226500
# Query next batch 226500 - 227000
# Query next batch 227000 - 227500
# Query next batch 227500 - 228000
# Query next batch 228000 - 228500
# Query next batch 228500 - 229000
# Query next batch 229000 - 229500
# Query next batch 229500 - 230000
# Query next batch 230000 - 230500
# Query next batch 230500 - 231000
# Query next batch 231000 - 231500
# Query next batch 231500 - 232000
# Query next batch 232000 - 232500
# Query next batch 232500 - 233000
# Query next batch 233000 - 233500
# Query next batch 233500 - 234000
# Query next batch 234000 - 234500
# Query next batch 234500 - 235000
# Query next batch 235000 - 235500
# Query next batch 235500 - 236000
# Query next batch 236000 - 236500
# Query next batch 236500 - 237000
# Query next batch 237000 - 237500
# Query next batch 237500 - 238000
# Query next batch 238000 - 238500
# Query next batch 238500 - 239000
# Query next batch 239000 - 239500
# Query next batch 239500 - 240000
# Query next batch 240000 - 240500
# Query next batch 240500 - 241000
# Query next batch 241000 - 241500
# Query next batch 241500 - 242000
# Query next batch 242000 - 242500
# Query next batch 242500 - 243000
# Query next batch 243000 - 243500
# Query next batch 243500 - 244000
# Query next batch 244000 - 244500
# Query next batch 244500 - 245000
# Query next batch 245000 - 245500
# Query next batch 245500 - 246000
# Query next batch 246000 - 246500
# Query next batch 246500 - 247000
# Query next batch 247000 - 247500
# Query next batch 247500 - 248000
# Query next batch 248000 - 248500
# Query next batch 248500 - 249000
# Query next batch 249000 - 249500
# Query next batch 249500 - 250000
# Query next batch 250000 - 250500
# Query next batch 250500 - 251000
# Query next batch 251000 - 251500
# Query next batch 251500 - 252000
# Query next batch 252000 - 252500
# Query next batch 252500 - 253000
# Query next batch 253000 - 253500
# Query next batch 253500 - 254000
# Query next batch 254000 - 254500
# Query next batch 254500 - 255000
# Query next batch 255000 - 255500
# Query next batch 255500 - 256000
# Query next batch 256000 - 256500
# Query next batch 256500 - 257000
# Query next batch 257000 - 257500
# Query next batch 257500 - 258000
# Query next batch 258000 - 258500
# Query next batch 258500 - 259000
# Query next batch 259000 - 259500
# Query next batch 259500 - 260000
# Query next batch 260000 - 260500
# Query next batch 260500 - 261000
# Query next batch 261000 - 261500
# Query next batch 261500 - 262000
# Query next batch 262000 - 262500
# Query next batch 262500 - 263000
# Query next batch 263000 - 263500
# Query next batch 263500 - 264000
# Query next batch 264000 - 264500
# Query next batch 264500 - 265000
# Query next batch 265000 - 265500
# Query next batch 265500 - 266000
# Query next batch 266000 - 266500
# Query next batch 266500 - 267000
# Query next batch 267000 - 267500
# Query next batch 267500 - 268000
# Query next batch 268000 - 268500
# Query next batch 268500 - 269000
# Query next batch 269000 - 269500
# Query next batch 269500 - 270000
# Query next batch 270000 - 270500
# Query next batch 270500 - 271000
# Query next batch 271000 - 271500
# Query next batch 271500 - 272000
# Query next batch 272000 - 272500
# Query next batch 272500 - 273000
# Query next batch 273000 - 273500
# Query next batch 273500 - 274000
# Query next batch 274000 - 274500
# Query next batch 274500 - 275000
# Query next batch 275000 - 275500
# Query next batch 275500 - 276000
# Query next batch 276000 - 276500
# Query next batch 276500 - 277000
# Query next batch 277000 - 277500
# Query next batch 277500 - 278000
# Query next batch 278000 - 278500
# Query next batch 278500 - 279000
# Query next batch 279000 - 279500
# Query next batch 279500 - 280000
# Query next batch 280000 - 280500
# Query next batch 280500 - 281000
# Query next batch 281000 - 281500
# Query next batch 281500 - 282000
# Query next batch 282000 - 282500
# Query next batch 282500 - 283000
# Query next batch 283000 - 283500
# Query next batch 283500 - 284000
# Query next batch 284000 - 284500
# Query next batch 284500 - 285000
# Query next batch 285000 - 285500
# Query next batch 285500 - 286000
# Query next batch 286000 - 286500
# Query next batch 286500 - 287000
# Query next batch 287000 - 287500
# Query next batch 287500 - 288000
# Query next batch 288000 - 288500
# Query next batch 288500 - 289000
# Query next batch 289000 - 289500
# Query next batch 289500 - 290000
# Query next batch 290000 - 290500
# Query next batch 290500 - 291000
# Query next batch 291000 - 291500
# Query next batch 291500 - 292000
# Query next batch 292000 - 292500
# Query next batch 292500 - 293000
# Query next batch 293000 - 293500
# Query next batch 293500 - 294000
# Query next batch 294000 - 294500
# Query next batch 294500 - 295000
# Query next batch 295000 - 295500
# Query next batch 295500 - 296000
# Query next batch 296000 - 296500
# Query next batch 296500 - 297000
# Query next batch 297000 - 297500
# Query next batch 297500 - 298000
# Query next batch 298000 - 298500
# Query next batch 298500 - 299000
# Query next batch 299000 - 299500
# Query next batch 299500 - 300000
# Query next batch 300000 - 300500
# Query next batch 300500 - 301000
# Query next batch 301000 - 301500
# Query next batch 301500 - 302000
# Query next batch 302000 - 302500
# Query next batch 302500 - 303000
# Query next batch 303000 - 303500
# Query next batch 303500 - 304000
# Query next batch 304000 - 304500
# Query next batch 304500 - 305000
# Query next batch 305000 - 305500
# Query next batch 305500 - 306000
# Query next batch 306000 - 306500
# Query next batch 306500 - 307000
# Query next batch 307000 - 307500
# Query next batch 307500 - 308000
# Query next batch 308000 - 308500
# Query next batch 308500 - 309000
# Query next batch 309000 - 309500
# Query next batch 309500 - 310000
# Query next batch 310000 - 310500
# Query next batch 310500 - 311000
# Query next batch 311000 - 311500
# Query next batch 311500 - 312000
# Query next batch 312000 - 312500
# Query next batch 312500 - 313000
# Query next batch 313000 - 313500
# Query next batch 313500 - 314000
# Query next batch 314000 - 314500
# Query next batch 314500 - 315000
# Query next batch 315000 - 315500
# Query next batch 315500 - 316000
# Query next batch 316000 - 316500
# Query next batch 316500 - 317000
# Query next batch 317000 - 317500
# Query next batch 317500 - 318000
# Query next batch 318000 - 318500
# Query next batch 318500 - 319000
# Query next batch 319000 - 319500
# Query next batch 319500 - 320000
# Query next batch 320000 - 320500
# Query next batch 320500 - 321000
# Query next batch 321000 - 321500
# Query next batch 321500 - 322000
# Query next batch 322000 - 322500
# Query next batch 322500 - 323000
# Query next batch 323000 - 323500
# Query next batch 323500 - 324000
# Query next batch 324000 - 324500
# Query next batch 324500 - 325000
# Query next batch 325000 - 325500
# Query next batch 325500 - 326000
# Query next batch 326000 - 326500
# Query next batch 326500 - 327000
# Query next batch 327000 - 327500
# Query next batch 327500 - 328000
# Query next batch 328000 - 328500
# Query next batch 328500 - 329000
# Query next batch 329000 - 329500
# Query next batch 329500 - 330000
# Query next batch 330000 - 330500
# Query next batch 330500 - 331000
# Query next batch 331000 - 331500
# Query next batch 331500 - 332000
# Query next batch 332000 - 332500
# Query next batch 332500 - 333000
# Query next batch 333000 - 333500
# Query next batch 333500 - 334000
# Query next batch 334000 - 334500
# Query next batch 334500 - 335000
# Query next batch 335000 - 335500
# Query next batch 335500 - 336000
# Query next batch 336000 - 336500
# Query next batch 336500 - 337000
# Query next batch 337000 - 337500
# Query next batch 337500 - 338000
# Query next batch 338000 - 338500
# Query next batch 338500 - 339000
# Query next batch 339000 - 339500
# Query next batch 339500 - 340000
# Query next batch 340000 - 340500
# Query next batch 340500 - 341000
# Query next batch 341000 - 341500
# Query next batch 341500 - 342000
# Query next batch 342000 - 342500
# Query next batch 342500 - 343000
# Query next batch 343000 - 343500
# Query next batch 343500 - 344000
# Query next batch 344000 - 344500
# Query next batch 344500 - 345000
# Query next batch 345000 - 345500
# Query next batch 345500 - 346000
# Query next batch 346000 - 346500
# Query next batch 346500 - 347000
# Query next batch 347000 - 347500
# Query next batch 347500 - 348000
# Query next batch 348000 - 348500
# Query next batch 348500 - 349000
# Query next batch 349000 - 349500
# Query next batch 349500 - 350000
# Query next batch 350000 - 350500
# Query next batch 350500 - 351000
# Query next batch 351000 - 351500
# Query next batch 351500 - 352000
# Query next batch 352000 - 352500
# Process finished

# %% [markdown]
# The training data should be ready now
